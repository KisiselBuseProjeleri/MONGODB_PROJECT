# %%
SEED_DATA = [
  {
    'genre': 'Fantasy',
    'title': 'The Lord of the Rings: The Fellowship of the Ring',
    'author': 'J.R.R. Tolkien',
    'year': 1954,
  },
  {
    'genre': 'Science Fiction',
    'title': 'Dune',
    'author': 'Frank Herbert',
    'year': 1965,
  },
  {
    'genre': 'Dystopian',
    'title': '1984',
    'author': 'George Orwell',
    'year': 1949,
  }
]

# %% [markdown]
# # Uygulamalar

# %% [markdown]
# # Soru 1

# %% [markdown]
# Mongo Db'den yeni bir veri tabanı ve collection oluşturup buna bağlanın.

# %%
from pymongo import MongoClient

# %%
client= MongoClient("mongodb+srv://buseayazoglu:buse123ayz@deneme1.hxzz7.mongodb.net/")

# %%
veri_tabanı = client['entellektüiller']
tablo = veri_tabanı['yazarlar']
tablo
# Out:
# Collection(Database(MongoClient(host=['deneme1-shard-00-01.hxzz7.mongodb.net:27017', 'deneme1-shard-00-00.hxzz7.mongodb.net:27017', 'deneme1-shard-00-02.hxzz7.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-9eshl0-shard-0', tls=True), 'etellektüiller'), 'yazarlar')

# %%
import random
new_data = []

for i in range(100):
    veriler = random.choice(SEED_DATA)
    yeni_veri = {
        'genre': veriler['genre'],
        'title': veriler['title'],
        'author': veriler['author'],
        'year': veriler['year']
    }
    new_data.append(yeni_veri)
for veri in new_data:
    print(veri)

# %%
tablo.insert_many(new_data)
# Out:
# InsertManyResult([ObjectId('675d9238eda13ffc5cab3b88'), ObjectId('675d9238eda13ffc5cab3b89'), ObjectId('675d9238eda13ffc5cab3b8a'), ObjectId('675d9238eda13ffc5cab3b8b'), ObjectId('675d9238eda13ffc5cab3b8c'), ObjectId('675d9238eda13ffc5cab3b8d'), ObjectId('675d9238eda13ffc5cab3b8e'), ObjectId('675d9238eda13ffc5cab3b8f'), ObjectId('675d9238eda13ffc5cab3b90'), ObjectId('675d9238eda13ffc5cab3b91'), ObjectId('675d9238eda13ffc5cab3b92'), ObjectId('675d9238eda13ffc5cab3b93'), ObjectId('675d9238eda13ffc5cab3b94'), ObjectId('675d9238eda13ffc5cab3b95'), ObjectId('675d9238eda13ffc5cab3b96'), ObjectId('675d9238eda13ffc5cab3b97'), ObjectId('675d9238eda13ffc5cab3b98'), ObjectId('675d9238eda13ffc5cab3b99'), ObjectId('675d9238eda13ffc5cab3b9a'), ObjectId('675d9238eda13ffc5cab3b9b'), ObjectId('675d9238eda13ffc5cab3b9c'), ObjectId('675d9238eda13ffc5cab3b9d'), ObjectId('675d9238eda13ffc5cab3b9e'), ObjectId('675d9238eda13ffc5cab3b9f'), ObjectId('675d9238eda13ffc5cab3ba0'), ObjectId('675d9238eda13ffc5cab
# ...

# %% [markdown]
# #Soru 2
# Kendiniz yukarıdikine benzer ama sadece 1 doküman oluşturup bu dokümanı mongodb ye aktarınız .Bunun için insert_many() methodunu kullanmaynız.

# %%
veri = {
    "genre": 'korku',
    'title': 'ölümcül köy',
    'author': 'buse',
    'year': 1987 

}
tablo.insert_one(veri)
# Out:
# InsertOneResult(ObjectId('675d94cceda13ffc5cab3bed'), acknowledged=True)

# %%
veriler = tablo.find({'author':'buse'})
for veri in veriler:
    print(veri)
# Out:
# {'_id': ObjectId('675d94cceda13ffc5cab3bed'), 'genre': 'korku', 'title': 'ölümcül köy', 'author': 'buse', 'year': 1987}

# %% [markdown]
# #Soru3
# author fieldı Gorge orwell olan documentin genre fieldını Scine_Fiction olarak güncelle ve yazdırınz.

# %%
sorgu = {'author' : 'George Orwell'}
tablo.update_many(sorgu,{'$set':{'genre':'Science_Fiction'}})
# Out:
# UpdateResult({'n': 22, 'electionId': ObjectId('7fffffff000000000000000a'), 'opTime': {'ts': Timestamp(1734186614, 22), 't': 10}, 'nModified': 22, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1734186614, 22), 'signature': {'hash': b'\xd7\xeb1\xfe\xec\x81\xa0gu>\xf1rc~\xe1\xb5\x14\xb6\x0b!', 'keyId': 7418578331844476932}}, 'operationTime': Timestamp(1734186614, 22), 'updatedExisting': True}, acknowledged=True)

# %%
veri = tablo.find(sorgu)
for data in veri:
    print(data)

# %% [markdown]
# #Soru 4
# Kitabın basım yılının 1950'de fazla olanları yazdırıp for döngüsü ile anlşılabilir bir format oluşturun bnu için '$gte' methoduu kullanın.

# %%
veriler = tablo.find({'year':{'$gte': 1950}})
for veri in veriler:
    print(f"""
          ----------------------------
          Kitap Türü: {veri['genre']}
        
          Kitap Adı: {veri['title']}
          
          Kitap Basım: {veri['author']}
          ----------------------------

    """)
# Out:
#           ----------------------------
#           Kitap Türü: Fantasy
#
#           Kitap Adı: The Lord of the Rings: The Fellowship of the Ring
#
#           Kitap Basım: J.R.R. Tolkien
#           ----------------------------
#
#
#
#           ----------------------------
#           Kitap Türü: Science Fiction
#
#           Kitap Adı: Dune
#
#           Kitap Basım: Frank Herbert
#           ----------------------------
#
#
#
#           ----------------------------
#           Kitap Türü: Science Fiction
#
#           Kitap Adı: Dune
#
#           Kitap Basım: Frank Herbert
#           ----------------------------
#
#
#
#           ----------------------------
#           Kitap Türü: Fantasy
#
#           Kitap Adı: The Lord of the Rings: The Fellowship of the Ring
#
#           Kitap Basım: J.R.R. Tolkien
#           ----------------------------
#
#
#
#           ----------------------------
#           Kitap Türü: Science Fiction
#
#           Kitap Adı: Dune
#
# ...
